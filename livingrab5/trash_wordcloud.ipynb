# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter
import numpy as np

# %%
# 네이버 페이지 분리수거 크롤링
genre1 = []

for i in range(10):
    print(f'{i}페이지 분석중....')
    url1 = (f'https://search.naver.com/search.naver?display=15&f=&filetype=0&page={i+2}&query=%EB%B6%84%EB%A6%AC%EC%88%98%EA%B1%B0&research_url=&sm=tab_pge&start={i*15+1}&where=web')
    html1 = requests.get(url1)
    bs = BeautifulSoup(html1.text, 'lxml')
    bs2 = bs.find('div', {'class':'api_txt_lines'}).get_text()
    genre1.append(bs2)
# Out:
# 0페이지 분석중....
# 1페이지 분석중....
# 2페이지 분석중....
# 3페이지 분석중....
# 4페이지 분석중....
# 5페이지 분석중....
# 6페이지 분석중....
# 7페이지 분석중....
# 8페이지 분석중....
# 9페이지 분석중....

# %%
print(genre1)
# Out:
# ["폐기물의 소각 및 재활용 등 처분을 용이하게 하기 위해, 그 재질마다 폐기물을 분류하고 그것을 수집하는 것을 말한다. '수거'는 지자체나 혹은 그곳과 계약된 수거 업체가 하는 것이고, 일상에서는 '배출'만을 하게 된다. 정책명도 수거자가 아닌 배출자가 기준인 분리배출로 되어 있다. 고로 항목명이나 평소에 이를 일컫는 용어도 사실은 분리배출이 맞다. 더 정확히 하면 분류배출이지만 정책명도 그렇고 분리배출이라고 쓴다...", '오늘의 분리수거의 리뷰를 읽고 고객 평점을 비교할 수 있습니다. 스크린샷을 보고 자세한 내용을 확인해 보세요. 오늘의 분리수거 항목을 다운로드하고 iPhone, iPad 및 iPod touch에서 즐겨보세요.', '재활용가능폐기물의 종류 및 세부품목별 분리배출 요령 종류 세부품목 분리배출요령 종이류 종이팩 내용물을 비우고 가급적 물로 헹군후 반드시 일반폐지와 혼합되지 않게 배출... 결합하고 분리가 어려운 플라스틱류 전구,전화기,소켓전지,완구,화장품용기 등 열에 잘 녹지 않는 플라스틱류 공사용PVC 또는 공사현장에서 사용한 폐스티로폼, 사용한 1회용품 용기... ', '투명 페트병은 겉에 붙은 비닐 라벨(상표띠)을 떼고, 깨끗이 씻어서 안에 담긴 이물질을 모두 비워야 한다. 그 후 발로 페트병을 압축한 뒤 뚜껑을 닫아 별도로 마련된 분리수거함에…', '창작만화 최근 창작만화 글쓰기 목록 | 이전글 | 다음글 [단편]분리수거[1] 다과령 (3985180) 활동내역 작성글 쪽지 마이피 출석일수 : 145일 | LV.9 Exp.11% 추천 2... 123.***.*** 분리수거하면 더 가치가 있을거에요 21.09.18 13:47 0 0 1 ON OFF 로그인이 필요합니다. 글쓰기 총 68776개의 글이 있습니다. 인증글 베스트 목록 검색2 분리수거 (1) ㅣ 다과령 12:28... 때수건의 그림일기 - 등... ', '아파트의 택배관리, 제초ㆍ전지작업 보조, 쓰레기 분리수거 등 업무는 경비업법의 시설경비업무 내지 그에 부수한 업무로 볼 수 없으므로, 아파트 경비원에게 위 업무를 수행하게 한 경비업자에 대한 경비업 허가 취소 처분은 적법하다는 법원 판결이 나왔다.수원지방법원 판결문에 따르면 경비업체 A회사는 2017년 4월 경기도 이천시에 있는 모 아파트와...', '분리수거 https://www.musinsa.com/?m=forum&uid=681171 복사하기 LV.7 Zelatore(EXP 23.76%) | 2021.10.14 09:01 | 148 |0|목록으로 신고 ※ 인기글 에 선정되었습니다. 해야겠네요. COOL 추천 (5) hmm.. 비추천 (0) URL 자기소개가 등록되지 않았습니다. 최근 등록 글 전체보기 - 부모님 new 21-12-19 19:16 - 이거 new 21-12-19 12:08 - 추위 대비 특... 자유게시판 분리수거 Community 자유게시판 패션 관련 글은 사소한... ', '화곡1동 주택가에 ‘이동식 재활용 분리수거함’ 설치 - 강서양천신문', '분리수거용기,마대걸이,재활용품분리수거함, 캔류분리수거함, 쓰레기분리수거함, 병류분리수거함, 주택가분리수거통, 해변분리수거함, 보급형분리수거함, 마대걸이분리수거함, 아파트분리수거함, 행사용분리수거함', '분리수거용기,마대걸이,재활용품분리수거함, 캔류분리수거함, 쓰레기분리수거함, 병류분리수거함, 주택가분리수거통, 해변분리수거함, 보급형분리수거함, 마대걸이분리수거함, 아파트분리수거함, 행사용분리수거함']

# %%
# 네이버 view
url2 = 'https://search.naver.com/search.naver?where=view&sm=tab_jum&query=%EB%B6%84%EB%A6%AC%EC%88%98%EA%B1%B0'
html2 = requests.get(url2)
bs3 = BeautifulSoup(html2.text, 'lxml')
bs4 = bs3.find_all('div', {'class':'api_txt_lines'})
bs4
# Out:
# [<div class="api_txt_lines dsc_txt">재활용수거의 단속이 심해진 것을 느끼셨을 겁니다. 어떻게 바뀌었는지, 자세한 <mark>분리수거</mark>의 방법은... 뚜껑을 분리 한 후 배출해야 합니다. 병류, 유리용기류는 알루미늄 테를 제거하고, 이물질을 제거한 후...</div>,
#  <div class="api_txt_lines dsc_txt">안내방송이고 <mark>분리수거</mark>하는 곳에 수요일9시목요일9시까지 <mark>분리수거</mark> 버리라고 하는데 왜 그렇게 하는건가요? 전 이해가 안되네요 물론 경비아저씨분들의 수고를 잘 압니다 저는 그분들을 뭐라하는게 아니고 이아파트에...</div>,
#  <div class="api_txt_lines dsc_txt">오늘은 재활용 <mark>분리수거</mark> 품목 중에 종이팩에 대해서 조금 이야기해 보겠습니다. 플라스틱과 더불어 재활용... 그래서 요즘은 아파트 단지에서도 따로 수거함을 마련하고, 이렇게 지자체에서 따로 수거를 해서 휴지로...</div>,
#  <div class="api_txt_lines dsc_txt">구분하여 <mark>분리수거</mark>함에 넣어 주면 끝 단! 우산의 재질이 천으로 되어있다면 분리 후 일반 쓰레기로 분류되는 천 재질은 종량제 봉투 버려주시면 됩니다 우산 관리하는 방법 사용한 우산을 그대로 방치해두면 곰팡이와...</div>,
#  <div class="api_txt_lines dsc_txt"><mark>분리수거</mark> 정리합니다~ *요녀석~ *<mark>분리수거</mark>도 엄청난 일이네요 *<mark>분리수거</mark>완료 *배터리만 정리~~</div>,
#  <div class="api_txt_lines dsc_txt">살아있는 꽃게 찌는법 게껍질 버리는법 (껍데기 <mark>분리수거</mark> 손질) 깨끗하고 싱싱한 상태로 왔네요~ 씻는 방법을... 잘 익은 꽃게들은 몸통과 등딱지를 분리해주는데요. 저희 어머니는 가위로 사정없이 잘라주었습니다. 먹게...</div>,
#  <div class="api_txt_lines dsc_txt">공간분리가 가능한 가정용<mark>분리수거</mark>함은 디자인부터 색상까지도 군더더기 없어 어디에 두고서 사용을 해도... 재활용수거함 놓고 사용하는것을 추천하고 싶습니다 20L 용량으로 여유있고 넉넉하게 사용이 가능해서...</div>,
#  <div class="api_txt_lines dsc_txt">스테인리스 단일 소재로 된 텀블러를사용하면 <mark>분리</mark>배출을 할 때 좋습니다!스테인리스 단일 소재 텀블러는재활용이 가능하다고 하는데요.깨끗하게 세척 후 <mark>분리수거</mark>를 할 때캔류에 버리면 됩니다. 복합 소재의 텀블러...</div>,
#  <div class="api_txt_lines dsc_txt">한번 먹고나면 쌓이게 되는 커피 캡슐들 네스프레소나 버츄오는 <mark>분리수거</mark>를 하려고 마음만 먹으면... 를 분리하고 #분리배출 을 해주었습니다 기왕 분리배출하는거 비닐쓰는것도 죄책감이 들어서 #생분해비닐 도 구매를...</div>,
#  <div class="api_txt_lines dsc_txt">형광등, 건전지 각각전용 <mark>수거</mark>함이 따로 있어요. 재활용 <mark>분리수거</mark> 4. 음식물 4-① 동물 뼈, 어패류/알 껍데기 뼈나 달걀 껍질, 조개 껍질은 일반 쓰레기로 <mark>분리</mark>해요. 만약 뼈에 살코기가  많이 남아 있다면...</div>,
#  <div class="api_txt_lines dsc_txt">특히 택배 박스, 종이 포장재에는 철핀, 운송장 등이 섞여 있을 수 있으므로 잘 제거해 <mark>분리</mark> 배출하자.  물에 젖은 종이 포장재는 말려서 <mark>분리수거</mark>해야 한다. 물이 아닌 화장품이 흥건히 젖었다면...</div>,
#  <div class="api_txt_lines dsc_txt">신발장도 작고 복도에 내놓을 수도 없는데 비닐봉지 끼워 쓰는 <mark>분리수거</mark>대도 써봤고 가로형으로 긴 분리형 쓰레기통도 썼는데 공간 차지 많고 누가 봐도 쓰레기통인데 집에 들어서자마자 주방, 거실에 보이니 이사하면서...</div>,
#  <div class="api_txt_lines dsc_txt">분명 현지인들은 <mark>분리수거</mark> 안하고 마구 버리는 사람들이 많아서 재활용 수거장을 크게 만들 필요성을 못 느낄듯 싶다. [공산품 품질] 홍콩에는 공장이 없으니, 공산품들은 대부분 중국산이다. 근데 가끔가다보면 여전히...</div>,
#  <div class="api_txt_lines dsc_txt">미니멀하게 사는데 더 미니멀 해지려고 정리중이에요 더 깔끔해지고 싶어요ㅠ <mark>분리수거</mark>함은 쓸데없는 자리차지와 돈낭비여서 집에 아예 없구요 코스트코 가방이랑 초록색 바구니 두개 놓고 쓰는데 더 깔끔하게 <mark>분리수거</mark>할...</div>,
#  <div class="api_txt_lines dsc_txt">아파트<mark>분리수거</mark>날 진공청소기 버려도 되나요?♡♡</div>,
#  <div class="api_txt_lines dsc_txt"><mark>분리수거</mark>를 안 하면 수거해 가지 않을뿐더러 벌금까지도 물 수 있으니까요. 그런데 리사이클링 활동에 참여하기가 쉽지만은 않습니다. 성분별로 분리해야 하고, 라벨도 떼야 하고, 찌꺼기는 깨끗이 씻어야 하고.. 등등...</div>,
#  <div class="api_txt_lines dsc_txt">제목 그대로 세탁소 옷걸이 <mark>분리수거</mark> 어떻게들 하시나요? 캔류(철)로 <mark>분리수거</mark> 가능하나요 아님 일반쓰레기로 버려야 할까요? 막상 버릴려니 아리쏭하네요 나의 고민 텍폴맘님들 지혜을 주세용</div>,
#  <div class="api_txt_lines dsc_txt"><mark>분리수거</mark>를 하고 온 바다소리 입니다. 지금 치아 치료중이라 맥주캔이 없으니... 확실히 <mark>분리</mark>할게 적어요. 하하하~ 깡통 할머니 슬프심 ㅠㅠ 또르르~ 언넝 치아치료하고 다시 마셔서 깡통 할머니에게 보탬이 되어야하겠어요!...</div>,
#  <div class="api_txt_lines dsc_txt">바나나껍질 &amp; 귤껍질 <mark>분리수거</mark> 가을이 되면서 맛있는 과일들이 정말 많이 생겨서 좋아요. 사과나 배와 같은... 이 중에서 바나나와 귤껍질 <mark>분리수거</mark>는 어떻게 하는지 한번 알아볼게요. 음식물 쓰레기 조건 ✓ 딱딱하지 않다....</div>,
#  <div class="api_txt_lines dsc_txt">아파트에 살때는 <mark>분리수거</mark>함이 있어 쓰레기 나올때마다 바로바로 치울수 있었는데 주택에 이사오고 나서는... 다 <mark>분리수거</mark>해서 종량제 봉투에 넣어야하는건지... 아님 일반봉투에 <mark>분리수거</mark>해도 되는건지 도와주세요</div>,
#  <div class="api_txt_lines dsc_txt"><mark>분리수거</mark>를 해야 하는 과정이 조금 거추장스럽기는 했는데요. 오늘은 캡슐 커피<mark>분리수거</mark> 방법과 찌꺼기 활용법에 대하여 함께 알아보도록 해요. 캡슐커피를 <mark>분리수거</mark>할때에 종이를 뜨게 되면 안에는 커피찌꺼기가...</div>,
#  <div class="api_txt_lines dsc_txt">차에 <mark>분리수거</mark> 한가득 갖고와서 <mark>분리수거</mark> 하는 사람들 몇번 봤어요 혹시나하고 차량 앞유리 봤는데 저희 아파트 스티커가 아니더라구요 지난번엔 라이더가 한가득 싣고와서 <mark>분리수거</mark>하고가고 관리비도 안내면서 무슨...</div>,
#  <div class="api_txt_lines dsc_txt">광명7동 717-2번지 상우아파트 담벼락도로가쪽에 음식물쓰레기통 과 재활용<mark>분리수거</mark>함을 만들어주세요.... 담벼락 밑으로 <mark>분리수거</mark>함과 음식물쓰레기통을 갔다놓으면 이렇 쓰레기 산이 되지는 않을것같아요. 연세있으신...</div>,
#  <div class="api_txt_lines dsc_txt">버리는 #쓰레기분리배출 이 얼마나 중요한지 알아보려고 합니다. 출처 : pixabay #<mark>분리수거</mark> 가 이루어지지 않은... 그 후 바짝 말려서 종이팩 수거함에 따로 버리시면 됩니다. 우유를 많이 드신다면 '닥터주부'라는 사이트...</div>,
#  <div class="api_txt_lines dsc_txt">2P와 3P가 있었는데 저는 집에서 가장 많이 버리는 페트병과 비닐, 캔과 병을 분리하기위해 3P <mark>분리수거</mark>함으로 구매했어요. 3P 기준 너비 65cm, 폭 24cm, 길이 약 37.2cm로 집안에 두고 사용하기에 딱 좋은 크기였어요. 폭도 30cm가...</div>,
#  <div class="api_txt_lines dsc_txt">득템후 <mark>분리수거</mark> 정리합니다~ *옆 카페에서 득템한 녀석~ *<mark>분리수거</mark>도 엄청난 일이네요 *<mark>분리수거</mark>완료 *배터리만 정리~~</div>,
#  <div class="api_txt_lines dsc_txt">이동식 케이스를 제거한 <mark>분리수거</mark>함의 모습인데요. 특별히 3개가 모두 필요없을때는 따로 분리를 해서 사용할 수 도 있고, 나중에 세척을 할때도 편리할 것 같았어요! 크기는 세로 37cm, 가로24cm 정도 되는데 너무 크지도...</div>,
#  <div class="api_txt_lines dsc_txt">참기름병다쓰고 어째버려야하나 보니 이렇게되있네요 우째 그냥 마대에 버려야하나요 아님 마개.라벨 제거하믄 <mark>분리수거</mark> 가능한건요... <mark>분리수거</mark>는 늠 어렵 ㅎㅎ 댓글에 <mark>분리수거</mark> 가능하시다고 알려주셔서...</div>,
#  <div class="api_txt_lines dsc_txt">뚜껑을 열고 남은 링 부분도 끊어내 분리할 수 있는데 이 기능은 이용하지 않아요. 제거하려다 피를 봤기 때문.... 서울환경연합 유튜브에서 올바른 <mark>분리수거</mark> 방법에 대해 알아보니 고리 부분은 일반인이 제거하기 힘드니...</div>,
#  <div class="api_txt_lines dsc_txt">득템후 <mark>분리수거</mark> 정리합니다~ *옆 카페에서 득템한 녀석~ *<mark>분리수거</mark>도 엄청난 일이네요 *<mark>분리수거</mark>완료 *배터리만 정리~~</div>]

# %%
bs4_list = []
for i in bs4:
    bs4_list.append(i.get_text())

# %%
print(bs4_list)
# Out:
# ['재활용수거의 단속이 심해진 것을 느끼셨을 겁니다. 어떻게 바뀌었는지, 자세한 분리수거의 방법은... 뚜껑을 분리 한 후 배출해야 합니다. 병류, 유리용기류는 알루미늄 테를 제거하고, 이물질을 제거한 후...', '안내방송이고 분리수거하는 곳에 수요일9시목요일9시까지 분리수거 버리라고 하는데 왜 그렇게 하는건가요? 전 이해가 안되네요 물론 경비아저씨분들의 수고를 잘 압니다 저는 그분들을 뭐라하는게 아니고 이아파트에...', '오늘은 재활용 분리수거 품목 중에 종이팩에 대해서 조금 이야기해 보겠습니다. 플라스틱과 더불어 재활용... 그래서 요즘은 아파트 단지에서도 따로 수거함을 마련하고, 이렇게 지자체에서 따로 수거를 해서 휴지로...', '구분하여 분리수거함에 넣어 주면 끝 단! 우산의 재질이 천으로 되어있다면 분리 후 일반 쓰레기로 분류되는 천 재질은 종량제 봉투 버려주시면 됩니다 우산 관리하는 방법 사용한 우산을 그대로 방치해두면 곰팡이와...', '분리수거 정리합니다~ *요녀석~ *분리수거도 엄청난 일이네요 *분리수거완료 *배터리만 정리~~', '살아있는 꽃게 찌는법 게껍질 버리는법 (껍데기 분리수거 손질) 깨끗하고 싱싱한 상태로 왔네요~ 씻는 방법을... 잘 익은 꽃게들은 몸통과 등딱지를 분리해주는데요. 저희 어머니는 가위로 사정없이 잘라주었습니다. 먹게...', '공간분리가 가능한 가정용분리수거함은 디자인부터 색상까지도 군더더기 없어 어디에 두고서 사용을 해도... 재활용수거함 놓고 사용하는것을 추천하고 싶습니다 20L 용량으로 여유있고 넉넉하게 사용이 가능해서...', '스테인리스 단일 소재로 된 텀블러를사용하면 분리배출을 할 때 좋습니다!스테인리스 단일 소재 텀블러는재활용이 가능하다고 하는데요.깨끗하게 세척 후 분리수거를 할 때캔류에 버리면 됩니다. 복합 소재의 텀블러...', '한번 먹고나면 쌓이게 되는 커피 캡슐들 네스프레소나 버츄오는 분리수거를 하려고 마음만 먹으면... 를 분리하고 #분리배출 을 해주었습니다 기왕 분리배출하는거 비닐쓰는것도 죄책감이 들어서 #생분해비닐 도 구매를...', '형광등,\xa0건전지\xa0각각전용\xa0수거함이\xa0따로\xa0있어요. 재활용\xa0분리수거\xa04.\xa0음식물 4-①\xa0동물\xa0뼈,\xa0어패류/알\xa0껍데기 뼈나\xa0달걀\xa0껍질,\xa0조개\xa0껍질은 일반\xa0쓰레기로\xa0분리해요. 만약\xa0뼈에\xa0살코기가\xa0 많이\xa0남아\xa0있다면...', '특히\xa0택배\xa0박스,\xa0종이\xa0포장재에는\xa0철핀,\xa0운송장\xa0등이\xa0섞여\xa0있을\xa0수\xa0있으므로\xa0잘\xa0제거해\xa0분리\xa0배출하자.\xa0 물에\xa0젖은\xa0종이\xa0포장재는\xa0말려서\xa0분리수거해야\xa0한다.\xa0물이\xa0아닌\xa0화장품이\xa0흥건히\xa0젖었다면...', '신발장도 작고 복도에 내놓을 수도 없는데 비닐봉지 끼워 쓰는 분리수거대도 써봤고 가로형으로 긴 분리형 쓰레기통도 썼는데 공간 차지 많고 누가 봐도 쓰레기통인데 집에 들어서자마자 주방, 거실에 보이니 이사하면서...', '분명 현지인들은 분리수거 안하고 마구 버리는 사람들이 많아서 재활용 수거장을 크게 만들 필요성을 못 느낄듯 싶다. [공산품 품질] 홍콩에는 공장이 없으니, 공산품들은 대부분 중국산이다. 근데 가끔가다보면 여전히...', '미니멀하게 사는데 더 미니멀 해지려고 정리중이에요 더 깔끔해지고 싶어요ㅠ 분리수거함은 쓸데없는 자리차지와 돈낭비여서 집에 아예 없구요 코스트코 가방이랑 초록색 바구니 두개 놓고 쓰는데 더 깔끔하게 분리수거할...', '아파트분리수거날 진공청소기 버려도 되나요?♡♡', '분리수거를 안 하면 수거해 가지 않을뿐더러 벌금까지도 물 수 있으니까요. 그런데 리사이클링 활동에 참여하기가 쉽지만은 않습니다. 성분별로 분리해야 하고, 라벨도 떼야 하고, 찌꺼기는 깨끗이 씻어야 하고.. 등등...', '제목 그대로 세탁소 옷걸이 분리수거 어떻게들 하시나요? 캔류(철)로 분리수거 가능하나요 아님 일반쓰레기로 버려야 할까요? 막상 버릴려니 아리쏭하네요 나의 고민 텍폴맘님들 지혜을 주세용', '분리수거를 하고 온 바다소리 입니다. 지금 치아 치료중이라 맥주캔이 없으니... 확실히 분리할게 적어요. 하하하~ 깡통 할머니 슬프심 ㅠㅠ 또르르~ 언넝 치아치료하고 다시 마셔서 깡통 할머니에게 보탬이 되어야하겠어요!...', '바나나껍질 & 귤껍질 분리수거 가을이 되면서 맛있는 과일들이 정말 많이 생겨서 좋아요. 사과나 배와 같은... 이 중에서 바나나와 귤껍질 분리수거는 어떻게 하는지 한번 알아볼게요. 음식물 쓰레기 조건 ✓ 딱딱하지 않다....', '아파트에 살때는 분리수거함이 있어 쓰레기 나올때마다 바로바로 치울수 있었는데 주택에 이사오고 나서는... 다 분리수거해서 종량제 봉투에 넣어야하는건지... 아님 일반봉투에 분리수거해도 되는건지 도와주세요', '분리수거를 해야 하는 과정이 조금 거추장스럽기는 했는데요. 오늘은 캡슐 커피분리수거 방법과 찌꺼기 활용법에 대하여 함께 알아보도록 해요. 캡슐커피를 분리수거할때에 종이를 뜨게 되면 안에는 커피찌꺼기가...', '차에 분리수거 한가득 갖고와서 분리수거 하는 사람들 몇번 봤어요 혹시나하고 차량 앞유리 봤는데 저희 아파트 스티커가 아니더라구요 지난번엔 라이더가 한가득 싣고와서 분리수거하고가고 관리비도 안내면서 무슨...', '광명7동 717-2번지 상우아파트 담벼락도로가쪽에 음식물쓰레기통 과 재활용분리수거함을 만들어주세요.... 담벼락 밑으로 분리수거함과 음식물쓰레기통을 갔다놓으면 이렇 쓰레기 산이 되지는 않을것같아요. 연세있으신...', "버리는 #쓰레기분리배출 이 얼마나 중요한지 알아보려고 합니다. 출처 : pixabay #분리수거 가 이루어지지 않은... 그 후 바짝 말려서 종이팩 수거함에 따로 버리시면 됩니다. 우유를 많이 드신다면 '닥터주부'라는 사이트...", '2P와 3P가 있었는데 저는 집에서 가장 많이 버리는 페트병과 비닐, 캔과 병을 분리하기위해 3P 분리수거함으로 구매했어요. 3P 기준 너비 65cm, 폭 24cm, 길이 약 37.2cm로 집안에 두고 사용하기에 딱 좋은 크기였어요. 폭도 30cm가...', '득템후 분리수거 정리합니다~ *옆 카페에서 득템한 녀석~ *분리수거도 엄청난 일이네요 *분리수거완료 *배터리만 정리~~', '이동식 케이스를 제거한 분리수거함의 모습인데요. 특별히 3개가 모두 필요없을때는 따로 분리를 해서 사용할 수 도 있고, 나중에 세척을 할때도 편리할 것 같았어요! 크기는 세로 37cm, 가로24cm 정도 되는데 너무 크지도...', '참기름병다쓰고 어째버려야하나 보니 이렇게되있네요 우째 그냥 마대에 버려야하나요 아님 마개.라벨 제거하믄 분리수거 가능한건요... 분리수거는 늠 어렵 ㅎㅎ 댓글에 분리수거 가능하시다고 알려주셔서...', '뚜껑을 열고 남은 링 부분도 끊어내 분리할 수 있는데 이 기능은 이용하지 않아요. 제거하려다 피를 봤기 때문.... 서울환경연합 유튜브에서 올바른 분리수거 방법에 대해 알아보니 고리 부분은 일반인이 제거하기 힘드니...', '득템후 분리수거 정리합니다~ *옆 카페에서 득템한 녀석~ *분리수거도 엄청난 일이네요 *분리수거완료 *배터리만 정리~~']

# %%
genre1.extend(bs4_list)

# %%
from konlpy.tag import Okt

okt = Okt()
noun_adj_list = []
for data in genre1:
    sentences_tag = okt.pos(data)
    # tag가 명사인 단어들만 noun_adj_list에 넣어준다.
    for word, tag in sentences_tag:
        if tag in ['Noun']:
            noun_adj_list.append(word)

# %%
noun_adj_list
# Out:
# ['폐기물',
#  '소각',
#  '및',
#  '재활용',
#  '등',
#  '처분',
#  '위해',
#  '그',
#  '재질',
#  '폐기물',
#  '분류',
#  '그것',
#  '수집',
#  '것',
#  '말',
#  '수거',
#  '지자체',
#  '곳',
#  '계약',
#  '수거',
#  '업체',
#  '것',
#  '일상',
#  '배출',
#  '정책',
#  '명도',
#  '수거',
#  '배출',
#  '기준',
#  '분리',
#  '배출',
#  '고로',
#  '항목',
#  '평소',
#  '용어',
#  '사실',
#  '분리',
#  '배출',
#  '더',
#  '분류',
#  '배출',
#  '정책',
#  '명도',
#  '분리',
#  '배출',
#  '오늘',
#  '분리수거',
#  '리뷰',
#  '고객',
#  '평점',
#  '비교',
#  '수',
#  '스크린샷',
#  '보고',
#  '내용',
#  '확인',
#  '오늘',
#  '분리수거',
#  '항목',
#  '다운로드',
#  '및',
#  '재활용',
#  '가능',
#  '폐기물',
#  '종류',
#  '및',
#  '부품',
#  '목별',
#  '분리',
#  '배출',
#  '요령',
#  '종류',
#  '세부',
#  '품목',
#  '분리',
#  '배출',
#  '요령',
#  '종이',
#  '류',
#  '종이팩',
#  '내용물',
#  '물',
#  '헹군후',
#  '반드시',
#  '폐지',
#  '혼합',
#  '배출',
#  '결합',
#  '분리',
#  '플라스틱',
#  '류',
#  '전구',
#  '전화기',
#  '소켓',
#  '전지',
#  '완구',
#  '화장품',
#  '용기',
#  '등',
#  '열',
#  '녹지',
#  '플라스틱',
#  '류',
#  '사용',
#  '현장',
#  '사용',
#  '폐',
#  '스티로폼',
#  '사용',
#  '용기',
#  '투명',
#  '페트병',
#  '겉',
#  '비닐',
#  '라벨',
#  '상표',
#  '띠',
#  '안',
#  '물질',
#  '모두',
#  '그',
#  '후',
#  '발',
#  '페트병',
#  '압축',
#  '뒤',
#  '뚜껑',
#  '별도',
#  '마련',
#  '분리수거',
#  '함',
#  '창작',
#  '만화',
#  '최근',
#  '창작',
#  '만화',
#  '글쓰기',
#  '목록',
#  '이전',
#  '글',
#  '다음',
#  '글',
#  '단편',
#  '분리수거',
#  '다과',
#  '령',
#  '활동',
#  '역',
#  '작성',
#  '글',
#  '쪽지',
#  '마이',
#  '피',
#  '출석',
#  '일수',
#  '추천',
#  '분리수거',
#  '더',
#  '가치',
#  '로그인',
#  '글쓰기',
#  '총',
#  '개',
#  '글',
#  '인증',
#  '글',
#  '베스트',
#  '목록',
#  '검색',
#  '분리수거',
#  '다과',
#  '령',
#  '때수건',
#  '그림',
#  '일기',
#  '등',
#  '아파트',
#  '택배',
#  '관리',
#  '제초',
#  '전지',
#  '작업',
#  '보조',
#  '쓰레기',
#  '분리수거',
#  '등',
#  '업무',
#  '경비',
#  '업법',
#  '시설',
#  '경비',
#  '업무',
#  '내지',
#  '그',
#  '부수',
#  '업무',
#  '볼',
#  '수',
#  '아파트',
#  '경비원',
#  '위',
#  '업무',
#  '수행',
#  '경비',
#  '업자',
#  '대한',
#  '경비',
#  '업',
#  '허가',
#  '취소',
#  '처분',
#  '법원',
#  '판결',
#  '수원지방법원',
#  '판결',
#  '문',
#  '경비',
#  '업체',
#  '회사',
#  '경기도',
#  '이천시',
#  '모',
#  '아파트',
#  '분리수거',
#  '복사',
#  '목록',
#  '신고',
#  '인기',
#  '글',
#  '선정',
#  '추천',
#  '비',
#  '추천',
#  '자기',
#  '소개',
#  '등록',
#  '최근',
#  '등록',
#  '글',
#  '전체',
#  '보기',
#  '부모님',
#  '거',
#  '추위',
#  '대비',
#  '특',
#  '자유게시판',
#  '분리수거',
#  '자유게시판',
#  '패션',
#  '관련',
#  '글',
#  '화곡',
#  '주택가',
#  '이동식',
#  '재활용',
#  '분리수거',
#  '함',
#  '설치',
#  '강서',
#  '양천',
#  '신문',
#  '분리수거',
#  '용기',
#  '마대',
#  '걸이',
#  '재활용품',
#  '분리수거',
#  '함',
#  '캔류',
#  '분리수거',
#  '함',
#  '쓰레기',
#  '분리수거',
#  '함',
#  '병류',
#  '분리수거',
#  '함',
#  '주택가',
#  '분리수거',
#  '통',
#  '해변',
#  '분리수거',
#  '함',
#  '보급',
#  '분리수거',
#  '함',
#  '마대',
#  '걸이',
#  '분리수거',
#  '함',
#  '아파트',
#  '분리수거',
#  '함',
#  '행',
#  '사용',
#  '분리수거',
#  '함',
#  '분리수거',
#  '용기',
#  '마대',
#  '걸이',
#  '재활용품',
#  '분리수거',
#  '함',
#  '캔류',
#  '분리수거',
#  '함',
#  '쓰레기',
#  '분리수거',
#  '함',
#  '병류',
#  '분리수거',
#  '함',
#  '주택가',
#  '분리수거',
#  '통',
#  '해변',
#  '분리수거',
#  '함',
#  '보급',
#  '분리수거',
#  '함',
#  '마대',
#  '걸이',
#  '분리수거',
#  '함',
#  '아파트',
#  '분리수거',
#  '함',
#  '행',
#  '사용',
#  '분리수거',
#  '함',
#  '재활용',
#  '수거',
#  '단속',
#  '것',
#  '분리수거',
#  '방법',
#  '뚜껑',
#  '분리',
#  '후',
#  '배출',
#  '병류',
#  '유리',
#  '용기',
#  '류',
#  '알루미늄',
#  '테',
#  '제거',
#  '물질',
#  '제거',
#  '후',
#  '안내',
#  '방송',
#  '분리수거',
#  '곳',
#  '수요일',
#  '분리수거',
#  '왜',
#  '가요',
#  '전',
#  '이해',
#  '경비',
#  '아저씨',
#  '수고',
#  '압니',
#  '저',
#  '그',
#  '아파트',
#  '오늘',
#  '재활용',
#  '분리수거',
#  '품목',
#  '중',
#  '종이팩',
#  '대해',
#  '조금',
#  '이야기',
#  '플라스틱',
#  '재활용',
#  '요즘',
#  '아파트',
#  '단지',
#  '수거',
#  '함',
#  '마련',
#  '지자체',
#  '수거',
#  '휴지',
#  '구분',
#  '분리수거',
#  '함',
#  '끝',
#  '단',
#  '우산',
#  '재질',
#  '천',
#  '분리',
#  '후',
#  '일반',
#  '쓰레기',
#  '분류',
#  '천',
#  '재질',
#  '종량제',
#  '봉투',
#  '우산',
#  '관리',
#  '방법',
#  '사용',
#  '우산',
#  '그대로',
#  '방치',
#  '곰팡이',
#  '분리수거',
#  '정리',
#  '녀석',
#  '분리수거',
#  '네',
#  '분리수거',
#  '완료',
#  '배터리',
#  '정리',
#  '꽃게',
#  '법',
#  '게',
#  '껍질',
#  '법',
#  '껍데기',
#  '분리수거',
#  '손질',
#  '상태',
#  '방법',
#  '꽃게',
#  '몸통',
#  '등',
#  '딱지',
#  '분리',
#  '저희',
#  '어머니',
#  '가위',
#  '공간',
#  '분리',
#  '가정',
#  '용',
#  '분리수거',
#  '함',
#  '디자인',
#  '색상',
#  '군더더기',
#  '어디',
#  '고서',
#  '사용',
#  '해도',
#  '재활용',
#  '수거',
#  '함',
#  '사용',
#  '추천',
#  '용량',
#  '여유',
#  '사용',
#  '스테인리스',
#  '단일',
#  '소재',
#  '텀블러',
#  '사용',
#  '분리',
#  '배출',
#  '때',
#  '스테인리스',
#  '단일',
#  '소재',
#  '텀블러',
#  '재활용',
#  '세척',
#  '후',
#  '분리수거',
#  '때캔류',
#  '복합',
#  '소재',
#  '텀블러',
#  '한번',
#  '커피',
#  '캡슐',
#  '네스프레소',
#  '버츄오',
#  '분리수거',
#  '마음',
#  '를',
#  '분리',
#  '기왕',
#  '분리',
#  '배출',
#  '비닐',
#  '죄책감',
#  '도',
#  '구매',
#  '형광등',
#  '건전지',
#  '전용',
#  '수거',
#  '함',
#  '재활용',
#  '분리수거',
#  '음식물',
#  '동물',
#  '뼈',
#  '어패류',
#  '알',
#  '껍데기',
#  '뼈',
#  '달걀',
#  '껍질',
#  '조개',
#  '껍질',
#  '일반',
#  '쓰레기',
#  '분리',
#  '만약',
#  '뼈',
#  '살코기',
#  '남아',
#  '택배',
#  '박스',
#  '종이',
#  '포장재',
#  '철핀',
#  '운송',
#  '등',
#  '수',
#  '제거',
#  '분리',
#  '배출',
#  '물',
#  '종이',
#  '포장재',
#  '분리수거',
#  '물이',
#  '화장품',
#  '흥건',
#  '신발장',
#  '작고',
#  '복도',
#  '수도',
#  '비닐봉지',
#  '분리수거',
#  '대도',
#  '가로',
#  '분리',
#  '쓰레기통',
#  '공간',
#  '차지',
#  '누가',
#  '쓰레기통',
#  '집',
#  '주방',
#  '거실',
#  '이사',
#  '분명',
#  '지인',
#  '분리수거',
#  '안',
#  '마구',
#  '사람',
#  '재활용',
#  '거장',
#  '크게',
#  '필요성',
#  '못',
#  '공산품',
#  '품질',
#  '홍콩',
#  '공장',
#  '공산품',
#  '대부분',
#  '중국산',
#  '미니',
#  '더',
#  '미니',
#  '해지',
#  '려고',
#  '정리',
#  '더',
#  '분리수거',
#  '함',
#  '자리',
#  '차지',
#  '돈',
#  '낭비',
#  '집',
#  '아예',
#  '코스트코',
#  '가방',
#  '초록색',
#  '바구니',
#  '개',
#  '더',
#  '분리수거',
#  '아파트',
#  '분리수거',
#  '날',
#  '진공청소기',
#  '분리수거',
#  '안',
#  '수거',
#  '가지',
#  '벌금',
#  '물',
#  '수',
#  '요',
#  '리',
#  '사이클링',
#  '활동',
#  '참여',
#  '분별',
#  '분리',
#  '라벨',
#  '찌꺼기',
#  '등등',
#  '제목',
#  '그대로',
#  '세탁소',
#  '옷',
#  '걸이',
#  '분리수거',
#  '게',
#  '캔류',
#  '철',
#  '로',
#  '분리수거',
#  '쓰레기',
#  '요',
#  '막상',
#  '아리',
#  '쏭',
#  '나',
#  '고민',
#  '텍폴맘님들',
#  '지혜',
#  '을',
#  '세용',
#  '분리수거',
#  '온',
#  '바다',
#  '소리',
#  '지금',
#  '치아',
#  '치료',
#  '맥주',
#  '캔',
#  '분리',
#  '하하',
#  '깡통',
#  '할머니',
#  '심',
#  '또르르',
#  '언넝',
#  '치아',
#  '치료',
#  '다시',
#  '깡통',
#  '할머니',
#  '보탬',
#  '바나나',
#  '껍질',
#  '귤',
#  '껍질',
#  '분리수거',
#  '가을',
#  '과일',
#  '정말',
#  '사과',
#  '배',
#  '이',
#  '중',
#  '바나나',
#  '귤',
#  '껍질',
#  '분리수거',
#  '한번',
#  '음식물',
#  '쓰레기',
#  '조건',
#  '아파트',
#  '살때',
#  '분리수거',
#  '함',
#  '쓰레기',
#  '때',
#  '주택',
#  '이사오',
#  '분리수거',
#  '종량제',
#  '봉투',
#  '봉투',
#  '분리수거',
#  '분리수거',
#  '과정',
#  '조금',
#  '거',
#  '추장',
#  '오늘',
#  '캡슐',
#  '커피',
#  '분리수거',
#  '방법',
#  '찌꺼기',
#  '활용',
#  '법',
#  '대하',
#  '해',
#  '캡슐',
#  '커피',
#  '분리수거',
#  '때',
#  '종이',
#  '안',
#  '커피',
#  '찌꺼기',
#  '차',
#  '분리수거',
#  '분리수거',
#  '사람',
#  '몇번',
#  '혹',
#  '시나',
#  '차량',
#  '앞',
#  '유리',
#  '저희',
#  '아파트',
#  '스티커',
#  '지난번',
#  '라이더',
#  '분리수거',
#  '관리',
#  '비도',
#  '안내면',
#  '무슨',
#  '광명',
#  '번지',
#  '상우',
#  '아파트',
#  '담벼락',
#  '도로',
#  '쪽',
#  '음식물',
#  '쓰레기통',
#  '과',
#  '재활용',
#  '분리수거',
#  '함',
#  '담벼락',
#  '밑',
#  '분리수거',
#  '함',
#  '음식물',
#  '쓰레기통',
#  '쓰레기',
#  '산이',
#  '연세',
#  '이',
#  '얼마나',
#  '출처',
#  '그',
#  '후',
#  '바짝',
#  '종이팩',
#  '수거',
#  '함',
#  '우유',
#  '닥터',
#  '주부',
#  '사이트',
#  '저',
#  '집',
#  '가장',
#  '페트병',
#  '비닐',
#  '캔',
#  '병',
#  '분리',
#  '위해',
#  '분리수거',
#  '함',
#  '구매',
#  '기준',
#  '너비',
#  '폭',
#  '길이',
#  '약',
#  '로',
#  '집안',
#  '사용',
#  '크기',
#  '폭도',
#  '득템',
#  '후',
#  '분리수거',
#  '정리',
#  '옆',
#  '카페',
#  '득템',
#  '녀석',
#  '분리수거',
#  '네',
#  '분리수거',
#  '완료',
#  '배터리',
#  '정리',
#  '이동식',
#  '케이스',
#  '제거',
#  '분리수거',
#  '함',
#  '모습',
#  '요',
#  '개',
#  '모두',
#  '때',
#  '분리',
#  '사용',
#  '수',
#  '도',
#  '나중',
#  '세척',
#  '때',
#  '것',
#  '크기',
#  '세로',
#  '가로',
#  '정도',
#  '참기름',
#  '병',
#  '어',
#  '그냥',
#  '마대',
#  '마개',
#  '라벨',
#  '제거',
#  '분리수거',
#  '건',
#  '분리수거',
#  '늠',
#  '댓글',
#  '분리수거',
#  '뚜껑',
#  '링',
#  '부분',
#  '분리',
#  '수',
#  '이',
#  '기능',
#  '이용',
#  '제거',
#  '피',
#  '때문',
#  '서울',
#  '환경',
#  '연합',
#  '유튜브',
#  '분리수거',
#  '방법',
#  '대해',
#  '고리',
#  '부분',
#  '일반인',
#  '제거',
#  '득템',
#  '후',
#  '분리수거',
#  '정리',
#  '옆',
#  '카페',
#  '득템',
#  '녀석',
#  '분리수거',
#  '네',
#  '분리수거',
#  '완료',
#  '배터리',
#  '정리']

# %%
# noun_adj_list[0]

# %%
for i in range(71):
    noun_adj_list.remove('분리수거')
# noun_adj_list.remove('교통사고')
# del noun_adj_list[0]
# noun_adj_list

# %%
noun_adj_list
counts = Counter(noun_adj_list)
tags = counts.most_common(50)
tags
# Out:
# [('함', 32),
#  ('분리', 21),
#  ('배출', 13),
#  ('사용', 12),
#  ('재활용', 11),
#  ('아파트', 11),
#  ('수거', 10),
#  ('쓰레기', 9),
#  ('분리수거', 9),
#  ('후', 8),
#  ('글', 8),
#  ('제거', 7),
#  ('정리', 7),
#  ('등', 6),
#  ('수', 6),
#  ('경비', 6),
#  ('껍질', 6),
#  ('그', 5),
#  ('더', 5),
#  ('용기', 5),
#  ('마대', 5),
#  ('걸이', 5),
#  ('방법', 5),
#  ('때', 5),
#  ('것', 4),
#  ('오늘', 4),
#  ('종이', 4),
#  ('류', 4),
#  ('안', 4),
#  ('추천', 4),
#  ('업무', 4),
#  ('커피', 4),
#  ('음식물', 4),
#  ('쓰레기통', 4),
#  ('득템', 4),
#  ('폐기물', 3),
#  ('및', 3),
#  ('재질', 3),
#  ('분류', 3),
#  ('종이팩', 3),
#  ('물', 3),
#  ('플라스틱', 3),
#  ('페트병', 3),
#  ('비닐', 3),
#  ('라벨', 3),
#  ('뚜껑', 3),
#  ('목록', 3),
#  ('개', 3),
#  ('관리', 3),
#  ('주택가', 3)]

# %%
# #불필요한 단어 제거하기 

# gen_word_r1=tags[-rm_obj]

# %%
# WordCloud를 생성한다.
from wordcloud import WordCloud
import platform
import matplotlib.pyplot as plt

if platform.system() == 'Windows':
    path = r'c:\Windows\Fonts\malgun.ttf'
elif platform.system() == 'Darwin': # Mac OS
    path = r'/System/Library/Fonts/AppleGothic'
else:
    path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'

wc = WordCloud(font_path=path, background_color="white", max_font_size=60)
cloud1 = wc.generate_from_frequencies(dict(tags))

# 생성된 WordCloud를 test.jpg로 보낸다.
#cloud.to_file('test.jpg')

plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud1, interpolation='bilinear')
plt.show()
