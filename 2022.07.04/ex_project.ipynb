# %%
# !pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# 모듈 로딩 ------------------------------------------------------
import pandas as pd


# 파일 관련 변수 선언 --------------------------------------------
DIR_PATH='../Data1/'
FILE_NAME=DIR_PATH+'aa.xlsx'

FILE_NAME
# Out:
# '../Data1/aa.xlsx'

# %%
# (1) CSV FILE => DataFrame 로딩 ------------------------------

memeDF=pd.read_excel(FILE_NAME)
memeDF
# Out:
#     ○ 규모별 매매가격지수 [2021.6 = 100.0] Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                           주택유형별        지역별      주택규모별         항목         단위
# 1                             아파트         전국        규모1       매매가격        NaN
# 2                             아파트         전국        규모2       매매가격        NaN
# 3                             아파트         전국        규모3       매매가격        NaN
# 4                             아파트         전국        규모4       매매가격        NaN
# ..                            ...        ...        ...        ...        ...
# 529                          단독주택         경남        규모2       매매가격        NaN
# 530                          단독주택         경남        규모3       매매가격        NaN
# 531                          단독주택         제주        규모1       매매가격        NaN
# 532                          단독주택         제주        규모2       매매가격        NaN
# 533                          단독주택         제주        규모3       매매가격        NaN
#
# ...

# %%
# 모듈 로딩 ------------------------------------------------------
import pandas as pd
import readxl as rx

# 파일 관련 변수 선언 --------------------------------------------
DIR_PATH='../Data1/'
FILE_NAME=DIR_PATH+'규모별매매가격지수.xls'

FILE_NAME
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       1 # 모듈 로딩 ------------------------------------------------------
#       2 import pandas as pd
# ----> 3 import readxl as rx
#       5 # 파일 관련 변수 선언 --------------------------------------------
#       6 DIR_PATH='../Data1/'
#
# ModuleNotFoundError: No module named 'readxl'
