# %%
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')

# %%
DIR='./대구광역시 일별 충전기별 사용현황_20220531.csv'

# %%
df=pd.read_csv(DIR, encoding='cp949')

# %%
df
# Out:
#                 일자     충전소ID          충전소명칭         위도          경도  충전기ID  \
# 0       2022-05-31  27110001  국채보상운동기념공원주차장  35.868863  128.600299      1
# 1       2022-05-31  27110001  국채보상운동기념공원주차장  35.868863  128.600299      2
# 2       2022-05-31  27110001  국채보상운동기념공원주차장  35.868863  128.600299      3
# 3       2022-05-31  27110002           대구시청  35.871039  128.601444      1
# 4       2022-05-31  27110002           대구시청  35.871039  128.601444      2
# ...            ...       ...            ...        ...         ...    ...
# 295259  2022-05-27  KSTX0001   대구시_KS택시주식회사  35.846120  128.623417      1
# 295260  2022-05-28  KSTX0001   대구시_KS택시주식회사  35.846120  128.623417      1
# 295261  2022-05-29  KSTX0001   대구시_KS택시주식회사  35.846120  128.623417      1
# 295262  2022-05-30  KSTX0001   대구시_KS택시주식회사  35.846120  128.623417      1
# 295263  2022-05-31  KSTX0001   대구시_KS택시주식회사  35.846120  128.623417      1
#
#        충전기타입  사용횟수         충전량
# 0         완속     3  110.590000
# ...

# %%
df.isnull().sum()
# Out:
# 일자       0
# 충전소ID    0
# 충전소명칭    0
# 위도       0
# 경도       0
# 충전기ID    0
# 충전기타입    0
# 사용횟수     0
# 충전량      1
# dtype: int64

# %%
df['일자'].unique()
# Out:
# array(['2022-05-31', '2022-05-30', '2022-05-29', ..., '2018-01-03',
#        '2018-01-02', '2018-01-01'], dtype=object)

# %%
df['충전기ID'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
df['충전기타입'].unique()
# Out:
# array(['완속', '급속'], dtype=object)

# %%
df['사용횟수'].unique()
# Out:
# array([    3,     1,     6,     5,     2,     7,     4,    10,     8,
#           11,    12,    15,     9,    14,    55,    13,    22,    18,
#           16,    21,    17,    23,    24,    25,    20,    33,    28,
#           31,    27,    19,    30,    48,    42,    26,    60,    34,
#           29,    49,   111,    32,    46,    64,    76,    35,    43,
#           41,    36,    37,    39,    45,    40, 13162, 21551,    38,
#           51,    53], dtype=int64)

# %%
df['충전량'][df['충전량'].isnull()]
# Out:
# 285972   NaN
# Name: 충전량, dtype: float64

# %%
df['충전량'].mean()
# Out:
# 95.56281113554583

# %%
df['충전량'].iloc[285972]
# Out:
# nan

# %%
df['충전량']= df['충전량'].fillna(df['충전량'].mean())

# %%
df['충전량'].iloc[285972]
# Out:
# 95.56281113554583

# %%
df['일자']
# Out:
# 0         2022-05-31
# 1         2022-05-31
# 2         2022-05-31
# 3         2022-05-31
# 4         2022-05-31
#              ...
# 295259    2022-05-27
# 295260    2022-05-28
# 295261    2022-05-29
# 295262    2022-05-30
# 295263    2022-05-31
# Name: 일자, Length: 295264, dtype: object

# %%
df['일자']=pd.to_datetime(df['일자'])

# %%
df['year']=df['일자'].dt.year
df['month']=df['일자'].dt.month
df['day']=df['일자'].dt.day
df['dayofweek']=df['일자'].dt.dayofweek

# %%
# 0번 화요일부터 시작
# 0 화요일, 1 수요일, 2 목요일, 3 금요일, 4 토요일, 5 일요일, 6 월요일
df['dayofweek'].unique()
# Out:
# array([1, 0, 6, 5, 4, 3, 2], dtype=int64)

# %%
df['dayofweek']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 295259    4
# 295260    5
# 295261    6
# 295262    0
# 295263    1
# Name: dayofweek, Length: 295264, dtype: int64

# %%
df.columns
# Out:
# Index(['일자', '충전소ID', '충전소명칭', '위도', '경도', '충전기ID', '충전기타입', '사용횟수', '충전량',
#        'year', 'month', 'day', 'dayofweek'],
#       dtype='object')

# %%
df['day']
# Out:
# 0         31
# 1         31
# 2         31
# 3         31
# 4         31
#           ..
# 295259    27
# 295260    28
# 295261    29
# 295262    30
# 295263    31
# Name: day, Length: 295264, dtype: int64

# %%
df.head(2)
# Out:
#           일자     충전소ID          충전소명칭         위도          경도  충전기ID 충전기타입  \
# 0 2022-05-31  27110001  국채보상운동기념공원주차장  35.868863  128.600299      1    완속
# 1 2022-05-31  27110001  국채보상운동기념공원주차장  35.868863  128.600299      2    완속
#
#    사용횟수     충전량  year  month  day  dayofweek
# 0     3  110.59  2022      5   31          1
# 1     1   22.38  2022      5   31          1

# %% [markdown]
# ## python 지도 시각화
# https://velog.io/@eodud0582/Folium

# %%
m = folium.Map(location=[35.868863,128.600299], zoom_strat=14)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m1 = folium.Map(location=[35.868863,128.600299], zoom_strat=14,
              tiles='Stamen Terrain')
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df['충전소명칭'].unique()
# Out:
# array(['국채보상운동기념공원주차장', '대구시청', '서문주차빌딩', '동인동행정복지센터', '갓바위공영3주차장',
#        '갓바위공영5주차장', '동구청', '동대구복합환승센터', '율하체육공원3주차장', '첨단의료산업진흥재단',
#        '환경공단안심관리소', 'DTC섬유박물관', '반야월공영주차장', '파계사 공영주차장', '해안동 행정복지센터',
#        '동촌유원지 입구 주차장', '대구지식서비스센터', '상공회의소', '신암공원', '아양아트센터',
#        '불로봉무동행정복지센터', '대구의료원', '서구국민체육센터', '서구청', '충전인프라 관제센터',
#        '대구환경공단(달서천)', '상중이동 행정복지센터', '서대구산업단지 근로자복지회관', '비산1동행정복지센터',
#        '평리3동행정복지센터', '충혼탑 주차장', '대명5동 행정복지센터', '이천동행정복지센터', '봉덕2동행정복지센터',
#        '대명9동행정복지센터', '농수산물도매시장', '매천역환승공영주차장', '북구청', '시청별관', '패션센터 주차장',
#        '관음공영주차장', '대구 부광교회', '구암동 행정복지센터', '한국도로공사 칠곡영업소', '유니버시아드 레포츠센터',
#        '아이빌', '대구체육관 주차장', '대구은행 제2본점영업부', '대구사격장', '동림플라자', '동천동행정복지센터',
#        '관음동행정복지센터', '검단동행정복지센터', '산격2동행정복지센터', '복현2동행정복지센터',
#        '두산오거리(두산스포츠 북동편 도로면)', '수성구청', '수성대학교 입구 우', '수성대학교 입구 좌',
#        '시지근린공원(누리타운 서편 도로면)', '어린이회관', '외환들공영주차장', '차량등록사업소1',
#        '파동교네거리주차장', '대구환경공단(지산)', '대구은행 파동지점', '지산근린공원 주차장', '명복공원 주차장',
# ...

# %%
df['위도'].unique()
# Out:
# array([35.868863  , 35.871039  , 35.868986  , 35.867832  , 35.970269  ,
#        35.969378  , 35.886499  , 35.879732  , 35.859579  , 35.878178  ,
#        35.868609  , 35.918978  , 35.872283  , 35.990802  , 35.882356  ,
#        35.8786    , 35.873304  , 35.871114  , 35.887914  , 35.8794319 ,
#        35.910223  , 35.859146  , 35.87404   , 35.871971  , 35.885112  ,
#        35.884411  , 35.866906  , 35.868532  , 35.881244  , 35.87594   ,
#        35.832849  , 35.843106  , 35.853161  , 35.843826  , 35.83736   ,
#        35.901647  , 35.914312  , 35.885169  , 35.890633  , 35.905449  ,
#        35.941098  , 35.922086  , 35.938912  , 35.934361  , 35.928012  ,
#        35.901768  , 35.89429   , 35.883874  , 35.912199  , 35.8953058 ,
#        35.937279  , 35.94423   , 35.913423  , 35.901755  , 35.895363  ,
#        35.827257  , 35.858433  , 35.855826  , 35.855772  , 35.842703  ,
#        35.846451  , 35.828748  , 35.866726  , 35.809905  , 35.829676  ,
# ...

# %%
df['경도'].unique()
# Out:
# array([128.600299 , 128.601444 , 128.581015 , 128.609096 , 128.725839 ,
#        128.726065 , 128.635956 , 128.632998 , 128.699723 , 128.736593 ,
#        128.680791 , 128.639976 , 128.70203  , 128.637078 , 128.671413 ,
#        128.649749 , 128.62504  , 128.6251   , 128.6221844, 128.6526291,
#        128.63941  , 128.541007 , 128.540583 , 128.558756 , 128.531275 ,
#        128.542192 , 128.545944 , 128.54476  , 128.569025 , 128.561308 ,
#        128.585379 , 128.587762 , 128.599083 , 128.601082 , 128.579219 ,
#        128.541827 , 128.542716 , 128.58269  , 128.60057  , 128.611857 ,
#        128.54481  , 128.548919 , 128.565813 , 128.539795 , 128.598231 ,
#        128.576858 , 128.602968 , 128.588519 , 128.521834 , 128.5172224,
#        128.558111 , 128.547317 , 128.627216 , 128.609292 , 128.625473 ,
#        128.62513  , 128.631104 , 128.649936 , 128.650062 , 128.70578  ,
#        128.625782 , 128.673994 , 128.63912  , 128.618785 , 128.621425 ,
# ...

# %%
m2 = folium.Map(location=[35.868863,128.600299], zoom_strat=14)

# 국채보상운동기념공원주차장
folium.Marker([35.868863,128.600299]).add_to(m2)

# 대구시청
folium.Marker([35.871039,128.601444],
               popup='<b>parking,/b').add_to(m2)

# 서문주차빌딩
folium.Marker([35.868986  ,128.581015 ],
             tooltip='<i>서문주차빌딩</i>').add_to(m2)

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df['충전소명칭'].unique()
# Out:
# array(['국채보상운동기념공원주차장', '대구시청', '서문주차빌딩', '동인동행정복지센터', '갓바위공영3주차장',
#        '갓바위공영5주차장', '동구청', '동대구복합환승센터', '율하체육공원3주차장', '첨단의료산업진흥재단',
#        '환경공단안심관리소', 'DTC섬유박물관', '반야월공영주차장', '파계사 공영주차장', '해안동 행정복지센터',
#        '동촌유원지 입구 주차장', '대구지식서비스센터', '상공회의소', '신암공원', '아양아트센터',
#        '불로봉무동행정복지센터', '대구의료원', '서구국민체육센터', '서구청', '충전인프라 관제센터',
#        '대구환경공단(달서천)', '상중이동 행정복지센터', '서대구산업단지 근로자복지회관', '비산1동행정복지센터',
#        '평리3동행정복지센터', '충혼탑 주차장', '대명5동 행정복지센터', '이천동행정복지센터', '봉덕2동행정복지센터',
#        '대명9동행정복지센터', '농수산물도매시장', '매천역환승공영주차장', '북구청', '시청별관', '패션센터 주차장',
#        '관음공영주차장', '대구 부광교회', '구암동 행정복지센터', '한국도로공사 칠곡영업소', '유니버시아드 레포츠센터',
#        '아이빌', '대구체육관 주차장', '대구은행 제2본점영업부', '대구사격장', '동림플라자', '동천동행정복지센터',
#        '관음동행정복지센터', '검단동행정복지센터', '산격2동행정복지센터', '복현2동행정복지센터',
#        '두산오거리(두산스포츠 북동편 도로면)', '수성구청', '수성대학교 입구 우', '수성대학교 입구 좌',
#        '시지근린공원(누리타운 서편 도로면)', '어린이회관', '외환들공영주차장', '차량등록사업소1',
#        '파동교네거리주차장', '대구환경공단(지산)', '대구은행 파동지점', '지산근린공원 주차장', '명복공원 주차장',
# ...

# %%
df['충전소명칭']=='국채보상운동기념공원주차장'
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 295259    False
# 295260    False
# 295261    False
# 295262    False
# 295263    False
# Name: 충전소명칭, Length: 295264, dtype: bool

# %%
df1=df[['충전소명칭','위도','경도']]
df1
# Out:
#                 충전소명칭         위도          경도
# 0       국채보상운동기념공원주차장  35.868863  128.600299
# 1       국채보상운동기념공원주차장  35.868863  128.600299
# 2       국채보상운동기념공원주차장  35.868863  128.600299
# 3                대구시청  35.871039  128.601444
# 4                대구시청  35.871039  128.601444
# ...               ...        ...         ...
# 295259   대구시_KS택시주식회사  35.846120  128.623417
# 295260   대구시_KS택시주식회사  35.846120  128.623417
# 295261   대구시_KS택시주식회사  35.846120  128.623417
# 295262   대구시_KS택시주식회사  35.846120  128.623417
# 295263   대구시_KS택시주식회사  35.846120  128.623417
#
# [295264 rows x 3 columns]

# %%
df1.iloc[:,0]
# Out:
# 0         국채보상운동기념공원주차장
# 1         국채보상운동기념공원주차장
# 2         국채보상운동기념공원주차장
# 3                  대구시청
# 4                  대구시청
#               ...
# 295259     대구시_KS택시주식회사
# 295260     대구시_KS택시주식회사
# 295261     대구시_KS택시주식회사
# 295262     대구시_KS택시주식회사
# 295263     대구시_KS택시주식회사
# Name: 충전소명칭, Length: 295264, dtype: object

# %%
# alldf=df1.iloc[:,0]==국채보상운동기념공원주차장

# %%
# for i in range(,295264):
#     df1.iloc[:i]

# %%
df1.iloc[:,0]
# Out:
# 0         국채보상운동기념공원주차장
# 1         국채보상운동기념공원주차장
# 2         국채보상운동기념공원주차장
# 3                  대구시청
# 4                  대구시청
#               ...
# 295259     대구시_KS택시주식회사
# 295260     대구시_KS택시주식회사
# 295261     대구시_KS택시주식회사
# 295262     대구시_KS택시주식회사
# 295263     대구시_KS택시주식회사
# Name: 충전소명칭, Length: 295264, dtype: object

# %%
# place= input('장소를 입력해 주세요: ')
# for i in range(0,5):
#     alldf=df1.iloc[:,{i}]=='place'

# print(alldf)

# %%
df.columns
# Out:
# Index(['일자', '충전소ID', '충전소명칭', '위도', '경도', '충전기ID', '충전기타입', '사용횟수', '충전량',
#        'year', 'month', 'day', 'dayofweek'],
#       dtype='object')

# %%
df1=df[['충전소명칭','위도','경도']]
df1
# Out:
#                 충전소명칭         위도          경도
# 0       국채보상운동기념공원주차장  35.868863  128.600299
# 1       국채보상운동기념공원주차장  35.868863  128.600299
# 2       국채보상운동기념공원주차장  35.868863  128.600299
# 3                대구시청  35.871039  128.601444
# 4                대구시청  35.871039  128.601444
# ...               ...        ...         ...
# 295259   대구시_KS택시주식회사  35.846120  128.623417
# 295260   대구시_KS택시주식회사  35.846120  128.623417
# 295261   대구시_KS택시주식회사  35.846120  128.623417
# 295262   대구시_KS택시주식회사  35.846120  128.623417
# 295263   대구시_KS택시주식회사  35.846120  128.623417
#
# [295264 rows x 3 columns]

# %%
df1.duplicated()
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 295259     True
# 295260     True
# 295261     True
# 295262     True
# 295263     True
# Length: 295264, dtype: bool

# %%
df2=df1.drop_duplicates(['충전소명칭'], keep='first')
df2
# Out:
#                    충전소명칭         위도          경도
# 0          국채보상운동기념공원주차장  35.868863  128.600299
# 3                   대구시청  35.871039  128.601444
# 5                 서문주차빌딩  35.868986  128.581015
# 8              동인동행정복지센터  35.867832  128.609096
# 9              갓바위공영3주차장  35.970269  128.725839
# ...                  ...        ...         ...
# 250773   대구시_고산2동 행정복지센터  35.843449  128.695181
# 259335  대구시_도동 측백향커뮤니티센터  35.919051  128.662238
# 266430         대구시_수성소방서  35.825251  128.644448
# 278634          대구시_태전공원  35.931466  128.544637
# 291854    대구시_유천동 행정복지센터  35.817079  128.513943
#
# [211 rows x 3 columns]

# %%
# https://specialscene.tistory.com/m/44
df2=df2.sort_index(ascending=True)
df2=df2.reset_index(drop=True)
df2
# Out:
#                 충전소명칭         위도          경도
# 0       국채보상운동기념공원주차장  35.868863  128.600299
# 1                대구시청  35.871039  128.601444
# 2              서문주차빌딩  35.868986  128.581015
# 3           동인동행정복지센터  35.867832  128.609096
# 4           갓바위공영3주차장  35.970269  128.725839
# ..                ...        ...         ...
# 206   대구시_고산2동 행정복지센터  35.843449  128.695181
# 207  대구시_도동 측백향커뮤니티센터  35.919051  128.662238
# 208         대구시_수성소방서  35.825251  128.644448
# 209          대구시_태전공원  35.931466  128.544637
# 210    대구시_유천동 행정복지센터  35.817079  128.513943
#
# [211 rows x 3 columns]

# %%
df2[df2['충전소명칭']=='대구시청'][['위도','경도']]
# Out:
#           위도          경도
# 1  35.871039  128.601444

# %%
# name = []
# for i in range(1,100):
#     name.append(i)

# print(name)

# %%
df2['충전소명칭'][3]
# Out:
# '동인동행정복지센터'

# %%
name1 = []
for i in range(0,211):
    name1.append(df2['충전소명칭'][i])

print(name1)
# Out:
# ['국채보상운동기념공원주차장', '대구시청', '서문주차빌딩', '동인동행정복지센터', '갓바위공영3주차장', '갓바위공영5주차장', '동구청', '동대구복합환승센터', '율하체육공원3주차장', '첨단의료산업진흥재단', '환경공단안심관리소', 'DTC섬유박물관', '반야월공영주차장', '파계사 공영주차장', '해안동 행정복지센터', '동촌유원지 입구 주차장', '대구지식서비스센터', '상공회의소', '신암공원', '아양아트센터', '불로봉무동행정복지센터', '대구의료원', '서구국민체육센터', '서구청', '충전인프라 관제센터', '대구환경공단(달서천)', '상중이동 행정복지센터', '서대구산업단지 근로자복지회관', '비산1동행정복지센터', '평리3동행정복지센터', '충혼탑 주차장', '대명5동 행정복지센터', '이천동행정복지센터', '봉덕2동행정복지센터', '대명9동행정복지센터', '농수산물도매시장', '매천역환승공영주차장', '북구청', '시청별관', '패션센터 주차장', '관음공영주차장', '대구 부광교회', '구암동 행정복지센터', '한국도로공사 칠곡영업소', '유니버시아드 레포츠센터', '아이빌', '대구체육관 주차장', '대구은행 제2본점영업부', '대구사격장', '동림플라자', '동천동행정복지센터', '관음동행정복지센터', '검단동행정복지센터', '산격2동행정복지센터', '복현2동행정복지센터', '두산오거리(두산스포츠 북동편 도로면)', '수성구청', '수성대학교 입구 우', '수성대학교 입구 좌', '시지근린공원(누리타운 서편 도로면)', '어린이회관', '외환들공영주차장', '차량등록사업소1', '파동교네거리주차장', '대구환경공단(지산)', '대구은행 파동지점', '지산근린공원 주차장', '명복공원 주차장', '대구은행 시지지점', '수성아트피아', '만촌3동행정복지센터', '중동행정복지센터', '상동행정복지센터', '지산1동행정복지센터', '고산3동행정복지센터', '달서구청', '대구도시철도공사', '두류공원(성당휴게소)', '서부법원 
# ...

# %%
name1[210]
# Out:
# '대구시_유천동 행정복지센터'

# %%
a=input(f'충전소명을 입력하시오: ')
print(df2[df2['충전소명칭']==a][['위도','경도']])
# Out:
# 충전소명을 입력하시오: 대구시_유천동 행정복지센터
#             위도          경도
# 210  35.817079  128.513943

# %%
# a1=input(f'충전소명을 입력하시오: ')
# print(df2[df2['충전소명칭']==a1][['위도','경도']][1:])

# %%
b=int(input(f'숫자: '))
c=name1[b]
print(c)
print(df2[df2['충전소명칭']==c][['위도','경도']])
# Out:
# 숫자: 1
# 대구시청
#           위도          경도
# 1  35.871039  128.601444

# %%
for i in range(211):
    b=int(input(f'숫자: '))
    c=name1[b]
    print(c)
    print(df2[df2['충전소명칭']==c][['위도','경도']])
    print('---------------------------------------------------')
    if b == 210:
        break
# Out:
# 숫자: 1
# 대구시청
#           위도          경도
# 1  35.871039  128.601444
# ---------------------------------------------------
# 숫자: 2
# 서문주차빌딩
#           위도          경도
# 2  35.868986  128.581015
# ---------------------------------------------------
# 숫자: 3
# 동인동행정복지센터
#           위도          경도
# 3  35.867832  128.609096
# ---------------------------------------------------
# 숫자:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [162], in <cell line: 1>()
#       1 for i in range(211):
# ----> 2     b=int(input(f'숫자: '))
#       3     c=name1[b]
#       4     print(c)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
folium.Map(location=[35.868863,128.600299], zoom_strat=14)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m3 = folium.Map(location=[35.868863,128.600299], zoom_strat=14)

for i in range(len(df2)):
    folium.Marker([df2.iloc[i,1],df2.iloc[i,2]]).add_to(m3)

m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
print(c)
# Out:
# None

# %%
df2[df2['충전소명칭'].str.contains('태전')]
# Out:
#                충전소명칭         위도          경도
# 165  대구시_태전1동 행정복지센터  35.924071  128.543235
# 204         대구시_태전2동  35.921467  128.548776
# 209         대구시_태전공원  35.931466  128.544637

# %%
# juso=input('충전소명을 입력하세요 : ')

# name=df2[df2['충전소명칭'].str.contains(juso)]

# m3 = folium.Map(location=[35.868863,128.600299], zoom_strat=14)

# for i in range(len(name)):
#     folium.Marker([df2.iloc[i,1],df2.iloc[i,2]]).add_to(m3)

# m3

# %%
juso=input('충전소명을 입력하세요 : ')

name=df2[df2['충전소명칭'].str.contains(juso)]

m3 = folium.Map(location=[35.868863,128.600299], zoom_strat=14)

for i in range(len(name)):
    folium.Marker([name.iloc[i,1],name.iloc[i,2]],tooltip=name.iloc[i,0]).add_to(m3)

m3

# %%
# for i in list(range(211)):
#     b=int(input(f'숫자: '))
#     c=name1[b]
#     print(c)
#     print(df2[df2['충전소명칭']==c][['위도','경도']])
#     print('---------------------------------------------------')

# %%
# m3 = folium.Map(location=[35.868863,128.600299], zoom_strat=14)

# # 국채보상운동기념공원주차장
# folium.Marker([35.868863,128.600299]).add_to(m3)

# # 대구시청
# folium.Marker([35.871039,128.601444],
#                popup='<b>parking,/b').add_to(m3)

# # 서문주차빌딩
# folium.Marker([35.868986  ,128.581015 ],
#              tooltip='<i>서문주차빌딩</i>').add_to(m3)

# # 동인동행정복지센터
# folium.Marker([35.867832  ,128.609096 ],
#              tooltip='<i>서문주차빌딩</i>').add_to(m3)

# # 갓바위공영3주차장
# folium.Marker([35.970269  ,128.725839 ],
#              tooltip='<i>서문주차빌딩</i>').add_to(m3)

# # 갓바위공영5주차장
# folium.Marker([35.969378  ,128.726065 ],
#              tooltip='<i>서문주차빌딩</i>').add_to(m3)

# m3
